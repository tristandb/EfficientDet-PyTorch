# %% [markdown]
# # EfficientDet

# %%
# !python3.7 train.py --dataset coco --coco_path ../../Datasets/COCO2017 --efficientdet --batch-size 32 --scaling-compound 0 --print-model-complexity
# Out:
# CUDA available: True
# loading annotations into memory...
# Done (t=16.03s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.61s)
# creating index...
# index created!
# Loaded pretrained weights for efficientnet-b0
# DataParallel(
#   2.009 M, 100.000% Params, 3.742 GMac, 100.000% MACs,
#   (module): EfficientDet(
#     2.009 M, 100.000% Params, 3.742 GMac, 100.000% MACs,
#     (efficientnet): Sequential(
#       1.114 M, 55.476% Params, 0.065 GMac, 1.726% MACs,
#       (0): Conv2dStaticSamePadding(
#         0.001 M, 0.043% Params, 0.0 GMac, 0.000% MACs, 3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False
#         (static_padding): ZeroPad2d(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, padding=(0, 1, 0, 1), value=0.0)
#       )
#       (1): BatchNorm2d(0.0 M, 0.003% Params, 0.004 GMac, 0.112% MACs, 32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (2): MBConvBlock(
# ...

# %%
# !pip3 install cython --user
# !pip3 install pycocotools --user
# !pip3 install efficientnet_pytorch --user
# !pip3 install pthflops --user
# Out:
# ...
# You are using pip version 18.1, however version 19.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# ...
# You are using pip version 18.1, however version 19.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# ...
# You are using pip version 18.1, however version 19.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# ...
# You are using pip version 18.1, however version 19.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
